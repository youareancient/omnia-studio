# %% [markdown]
# # YouTube Voiceover Studio - Google Colab Notebook
#
# Run this notebook in [Google Colab](https://colab.research.google.com/) to host and edit YouTube Voiceover Studio online for free.

# %%
# 1. Install dependencies & ffmpeg
# !pip install -r requirements.txt
# !apt-get update -qq && apt-get install -y -qq ffmpeg

# %%
# 2. Run YouTube Voiceover Studio
# !python app.py
