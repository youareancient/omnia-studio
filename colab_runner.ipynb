# %% [markdown]
# # 🎬 YouTube Voiceover Studio — Google Colab Web App Runner
#
# Run the complete **YouTube Voiceover Studio Web App** directly in Google Colab for free.

# %%
# @title 1. Setup Environment & Install Dependencies
import os
if not os.path.exists('app.py'):
    # !git clone https://github.com/youareancient/youtube-voiceover-studio.git
    # %cd youtube-voiceover-studio

# !pip install -q -r requirements.txt
# !apt-get update -qq && apt-get install -y -qq ffmpeg

# %%
# @title 2. Launch Studio Web App (Click link below after running)
try:
    from google.colab import output
    output.serve_kernel_port_as_window(7860)
    print("🔗 Web app available at the Colab port proxy link above!")
except Exception as e:
    print("Running locally...")

# !python app.py
